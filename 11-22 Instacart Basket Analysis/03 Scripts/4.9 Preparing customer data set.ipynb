# %% [markdown]
# # 01 Importing libraries and dataset

# %%
#Importing libraries

import pandas as pd
import numpy as np
import os

# %%
#Creating path
path = r'C:\Users\zunai\OneDrive\Documents\Data Analytics\Achivement 4\11-22 Instacart Basket Analysis'

# %%
#Importing data sets
df_ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared data', 'orders_products_merged_update2.pkl'))

# %%
df_cust = pd.read_csv(os.path.join(path, '02 Data', 'Original data', 'customers.csv'), index_col = False)

# %%
#Check
df_ords_prods_merge.shape
# Out:
# (32404859, 24)

# %%
df_ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2398795        1             2          3                  7
# 2    473747        1             3          3                 12
# 3   2254736        1             4          4                  7
# 4    431534        1             5          4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                   999.0         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  ...    price_range_loc     Busiest day  Busiest days  \
# 0         Soda  ...  Mid-range product  Regularly busy  Regular days
# ...

# %%
df_cust.shape
# Out:
# (206209, 10)

# %%
df_cust.head()
# Out:
#    user_id First Name    Surnam  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %% [markdown]
# # 02 Data wrangling

# %% [markdown]
# ### Re-naming columns

# %%
df_cust.rename(columns= {'First Name' : 'first_name', 'Surnam' : 'surname','Gender' : 'gender','STATE' : 'state',
                          'Age' : 'age', 'n_dependants': 'no_of_dependants', 'fam_status' : 'marital_status'}, inplace = True)

# %%
df_cust.head()
# Out:
#    user_id first_name   surname  gender       state  age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    no_of_dependants marital_status  income
# 0                 3        married  165665
# 1                 0         single   59285
# 2                 2        married   99568
# 3                 0         single   42049
# 4                 1        married   40374

# %% [markdown]
# # 03 Consistency checks

# %%
#Descriptive analysis
df_cust.describe()
# Out:
#              user_id            age  no_of_dependants         income
# count  206209.000000  206209.000000     206209.000000  206209.000000
# mean   103105.000000      49.501646          1.499823   94632.852548
# std     59527.555167      18.480962          1.118433   42473.786988
# min         1.000000      18.000000          0.000000   25903.000000
# 25%     51553.000000      33.000000          0.000000   59874.000000
# 50%    103105.000000      49.000000          1.000000   93547.000000
# 75%    154657.000000      66.000000          3.000000  124244.000000
# max    206209.000000      81.000000          3.000000  593901.000000

# %%
#Check data types
df_cust.dtypes
# Out:
# user_id              int64
# first_name          object
# surname             object
# gender              object
# state               object
# age                  int64
# date_joined         object
# no_of_dependants     int64
# marital_status      object
# income               int64
# dtype: object

# %%
#Check for duplicates
df_cust[df_cust.duplicated()]
# Out:
# Empty DataFrame
# Columns: [user_id, first_name, surname, gender, state, age, date_joined, no_of_dependants, marital_status, income]
# Index: []

# %% [markdown]
# #### No duplicates found

# %%
#Check for missing values
df_cust.isnull().sum()
# Out:
# user_id                 0
# first_name          11259
# surname                 0
# gender                  0
# state                   0
# age                     0
# date_joined             0
# no_of_dependants        0
# marital_status          0
# income                  0
# dtype: int64

# %%
#View missing data
df_cust[df_cust['first_name'].isnull()==True]
# Out:
#         user_id first_name   surname  gender         state  age date_joined  \
# 53        76659        NaN   Gilbert    Male      Colorado   26    1/1/2017
# 73        13738        NaN     Frost  Female     Louisiana   39    1/1/2017
# 82        89996        NaN    Dawson  Female        Oregon   52    1/1/2017
# 99        96166        NaN   Oconnor    Male      Oklahoma   51    1/1/2017
# 105       29778        NaN    Dawson  Female          Utah   63    1/1/2017
# ...         ...        ...       ...     ...           ...  ...         ...
# 206038   121317        NaN    Melton    Male  Pennsylvania   28   3/31/2020
# 206044   200799        NaN  Copeland  Female        Hawaii   52    4/1/2020
# 206090   167394        NaN     Frost  Female        Hawaii   61    4/1/2020
# 206162   187532        NaN     Floyd  Female    California   39    4/1/2020
# 206171   116898        NaN   Delgado  Female      Colorado   23    4/1/2020
#
#         no_of_dependants marital_status  income
# ...

# %% [markdown]
# #### There are 11259 missing values for the first_name column (~5% of the data set). Although we could potentially remove the missing data without having too much of an impact on the outcome of our analysis, I will leave the missing values as we don't need the first_name to identify customers as we have the user_id column to identify them instead.

# %%
#Checking for columns with mixed data types
for col in df_cust.columns.tolist():
  weird = (df_cust[[col]].applymap(type) != df_cust[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_cust[weird]) > 0:
    print (col)
# Out:
# first_name

# %% [markdown]
# #### First_name column has a mixed data type

# %%
#Check the data type of 'first_name'
df_cust['first_name'].dtype
# Out:
# dtype('O')

# %%
#Convert first_name data type to string
df_cust['first_name'] = df_cust['first_name'].astype('str')

# %%
#Re-run check for columns with mixed data types
for col in df_cust.columns.tolist():
  weird = (df_cust[[col]].applymap(type) != df_cust[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_cust[weird]) > 0:
    print (col)

# %% [markdown]
# # 04 Reduce data types to save RAM

# %%
df_cust['age'] = df_cust['age'].astype('int8')

# %%
df_cust['no_of_dependants'] = df_cust['no_of_dependants'].astype('int8')

# %%
df_cust['income'] = df_cust['income'].astype('int32')

# %%
df_cust['user_id'] = df_cust['user_id'].astype('str')

# %%
#Check for updated data types
df_cust.dtypes
# Out:
# user_id             object
# first_name          object
# surname             object
# gender              object
# state               object
# age                   int8
# date_joined         object
# no_of_dependants      int8
# marital_status      object
# income               int32
# dtype: object

# %% [markdown]
# # 05 Merge df_cust dataframe with df_ords_prods_merge

# %% [markdown]
# #### Common column between df_cust and df_ords_prods_merge is user_id

# %%
#Check user_id data type in df_ords_prods_merge
df_ords_prods_merge['user_id'].dtype
# Out:
# dtype('int64')

# %%
#Convert user_id in df_ords_prods_merge to string
df_ords_prods_merge['user_id'] = df_ords_prods_merge['user_id'].astype('str')

# %%
df_ords_prods_merge.dtypes
# Out:
# order_id                            int64
# user_id                            object
# order_number                        int64
# order_dow                           int64
# order_hour_of_day                   int64
# days_since_prior_order            float64
# product_id                          int64
# add_to_cart_order                   int64
# reordered                           int64
# product_name                       object
# aisle_id                            int64
# department_id                       int64
# prices                            float64
# _merge                           category
# price_range_loc                    object
# Busiest day                        object
# Busiest days                       object
# Busiest_hours_of_day               object
# max_order                           int64
# loyalty_flag                       object
# average_price                     float64
# spender_flag                       object
# ...

# %%
#Merge df_ords_prods_merge and df_cust
df_ords_prods_cust = df_ords_prods_merge.merge(df_cust, on = 'user_id')

# %%
#Checks on merged dataframe
df_ords_prods_cust.shape
# Out:
# (32404859, 33)

# %%
df_ords_prods_cust.head()
# Out:
#    order_id user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329       1             1          2                  8
# 1   2398795       1             2          3                  7
# 2    473747       1             3          3                 12
# 3   2254736       1             4          4                  7
# 4    431534       1             5          4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                   999.0         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  ...         frequency_flag  first_name  surname  gender  \
# 0         Soda  ...  Non-frequent customer       Linda   Nguyen  Female
# ...

# %% [markdown]
# # 07 Exporting data

# %%
df_ords_prods_cust.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'full_instacart_data.pkl'))
